# %% [markdown]
# # <a id='toc1_'></a>[Post-processing of results (second part)](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Post-processing of results (second part)](#toc1_)
#   - [Preliminaries](#toc1_1_)
#     - [Import libraries](#toc1_1_1_)
#     - [Utility functions](#toc1_1_2_)
#     - [Utilities for the summarized version](#toc1_1_3_)
#     - [Utilities for the full version](#toc1_1_4_)
#     - [Load the results](#toc1_1_5_)
#   - [Basin: E12GM](#toc1_2_)
#     - [Versione full](#toc1_2_1_)
#       - [PCMCI](#toc1_2_1_1_)
#       - [TEFS](#toc1_2_1_2_)
#     - [Versione summarized](#toc1_2_2_)
#       - [PCMCI](#toc1_2_2_1_)
#       - [TEFS](#toc1_2_2_2_)
#     - [Versione full senza CMI](#toc1_2_3_)
#       - [TEFS](#toc1_2_3_1_)
#     - [TEFS as wrapper on E12GM](#toc1_2_4_)
#     - [Linking the wrapper to the original filter method](#toc1_2_5_)
#   - [Basin: Ticino](#toc1_3_)
#     - [Versione full](#toc1_3_1_)
#       - [PCMCI](#toc1_3_1_1_)
#       - [TEFS](#toc1_3_1_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Preliminaries](#toc0_)

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Import libraries](#toc0_)

# %%
import os

os.chdir(os.path.dirname(os.path.abspath(__file__)))

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import thesis.constants as constants
import thesis.file_management as file_management
from sklearn.model_selection import (
    KFold,
    TimeSeriesSplit,
)
from tefs.metrics import regression_analysis
from thesis import datasets_and_configurations_loaders

# %% [markdown]
# Set the retina resolution

# %%
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Enable the use of LaTeX for plots.

# %%
plt.rc("text", usetex=True)

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Utility functions](#toc0_)
#
# General purpose formatter functions, valid for all stylers.

# %%
def makecell_code_formatter(x):
    """
    Format a string to be used in a LaTeX table cell. Specifically, given a list of names, it will format them as a
    single column with each name in a separate row and in a monospaced font.
    """
    elements = x.split(" ")
    formatted_elements = [f"\\texttt{{{element}}}" for element in elements]
    return "\\makecell[l]{" + "\\\\ ".join(formatted_elements) + "}"


def format_time(seconds):
    """
    Format a time in seconds to a human-readable format.
    """
    return f"{seconds:.3f}s"


def highlight_row(s, row_indexes, color):
    """
    Highlight the given row indexes of Series s with the given color.
    """
    if "test" in s.name.lower():
        return ["" for _ in s]  # No styling for columns with "test" in their name
    return ["background-color: " + color if i in row_indexes else "" for i in range(len(s))]


def color_direction(v):
    """
    Color the text of a cell according to the direction of the value.
    """
    color = "black"
    if v == "backward":
        color = "red"
    elif v == "forward":
        color = "blue"
    return f"color: {color}"

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[Utilities for the summarized version](#toc0_)
#
# Some utilities are specific to the summarized version of the table of results.

# %% [markdown]
# For the PCMCI version.

# %%
def make_pcmci_pretty(styler):
    styler.format(subset=["score_r2_lag", "score_r2_lag_ar"], precision=3)
    styler.background_gradient(cmap="Greens", subset=["score_r2_lag", "score_r2_lag_ar"], vmin=0, vmax=0.5)
    styler.format(subset=["execution_time"], precision=2)
    # styler.format(formatter=format_time, subset=["execution_time"])
    styler.background_gradient(cmap="Reds", subset=["execution_time"], vmax=8000)
    return styler


from pandas.io.formats.style_render import _escape_latex

# I lost too much time trying to figure out why I can't format the "names" of the indexes (to escape them)
# The guy who wrote it didn't allow for this possibility, but thankfully (https://stackoverflow.com/questions/72716879/is-there-a-function-to-format-the-index-name-in-a-pandas-styler-dataframe-style)
# he proposed a workaround and opened a github issue (https://github.com/pandas-dev/pandas/issues/47489)
# But he didn't realize that this doesn't work on multi-indexes, so I had to modify his code a bit


def export_pcmci_df_to_latex(df, target_file, code_escaped_columns=[]):
    temp_df = df.copy()
    for level in range(temp_df.index.nlevels):
        if temp_df.index.get_level_values(level).name is not None:
            temp_df.index.set_names(_escape_latex(temp_df.index.get_level_values(level).name), level=level, inplace=True)
    for level in range(temp_df.columns.nlevels):
        if temp_df.columns.get_level_values(level).name is not None:
            temp_df.columns.set_names(_escape_latex(temp_df.columns.get_level_values(level).name), level=level, inplace=True)

    with open(target_file, "w") as f:
        f.write(
            temp_df.style.pipe(make_pcmci_pretty)
            .format_index(escape="latex", axis="index")
            .format_index(escape="latex", axis="columns")
            .format(formatter=makecell_code_formatter, escape="latex", subset=code_escaped_columns)
            .to_latex(hrules=True, clines="all;index", convert_css=True, column_format="cclccccrr")
        )

# %% [markdown]
# For the TEFS version.

# %%
def make_te_pretty(styler):
    styler.format(subset=["score_r2_lag", "score_r2_lag_ar"], precision=3)
    styler.background_gradient(cmap="Greens", subset=["score_r2_lag", "score_r2_lag_ar"], vmin=0, vmax=0.5)
    styler.format(subset=["execution_time"], precision=2)
    styler.background_gradient(cmap="Reds", subset=["execution_time"], vmax=8000)
    return styler


def export_te_df_to_latex(df, target_file, code_escaped_columns=[]):
    temp_df = df.copy()
    for level in range(temp_df.index.nlevels):
        if temp_df.index.get_level_values(level).name is not None:
            temp_df.index.set_names(_escape_latex(temp_df.index.get_level_values(level).name), level=level, inplace=True)
    for level in range(temp_df.columns.nlevels):
        if temp_df.columns.get_level_values(level).name is not None:
            temp_df.columns.set_names(_escape_latex(temp_df.columns.get_level_values(level).name), level=level, inplace=True)

    with open(target_file, "w") as f:
        f.write(
            temp_df.style.pipe(make_te_pretty)
            .format_index(escape="latex", axis="index")
            .format_index(escape="latex", axis="columns")
            .format(formatter=makecell_code_formatter, escape="latex", subset=code_escaped_columns)
            .to_latex(hrules=True, clines="all;index", convert_css=True, column_format="cclccccrr")
        )

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[Utilities for the full version](#toc0_)
#
# Some utilities are specific to the full version of the table of results.

# %% [markdown]
# For the PCMCI version.

# %%
def make_pcmci_all_pretty(styler):
    styler.format(subset=["score_r2", "score_r2_lag", "score_r2_lag_ar"], precision=3)
    styler.background_gradient(cmap="Greens", subset=["score_r2", "score_r2_lag", "score_r2_lag_ar"], vmin=0, vmax=0.5)
    styler.format(formatter=format_time, subset=["execution_time"])
    styler.background_gradient(cmap="Reds", subset=["execution_time"], vmax=8000)
    return styler


def export_results_dataframe_pcmci(df: pd.DataFrame, target_file: str):
    with open(target_file, "w") as f:
        f.write(
            df.style.pipe(make_pcmci_all_pretty)
            .format_index(escape="latex", axis=1)
            .format(formatter=makecell_code_formatter, escape="latex", subset=["selected_features", "dataset", "algorithm", "independencetest"])
            .to_latex(hrules=True, clines="all;data", convert_css=True, column_format="llccclllcr")
        )

# %% [markdown]
# For the TEFS version.

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.html
# https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.format.html
# https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.to_latex.html
# https://www.youtube.com/watch?v=JGefS6WPm1E
# https://tex.stackexchange.com/questions/2441/how-to-add-a-forced-line-break-inside-a-table-cell
def make_te_all_pretty(styler):
    styler.format(subset=["score_r2", "score_r2_lag", "score_r2_lag_ar"], precision=3)
    styler.background_gradient(cmap="Greens", subset=["score_r2", "score_r2_lag", "score_r2_lag_ar"], vmin=0, vmax=0.5)
    #styler.map(color_direction, subset=["direction"])
    styler.format(formatter=format_time, subset=["execution_time"])
    styler.background_gradient(cmap="Reds", subset=["execution_time"], vmax=8000)
    # styler.apply(highlight_row, row_indexes=[5,7], color='yellow', axis=0)
    return styler


def export_results_dataframe_te(df: pd.DataFrame, target_file: str):
    with open(target_file, "w") as f:
        f.write(
            df.style.pipe(make_te_all_pretty)
            .format_index(escape="latex", axis=1)
            .format(formatter=makecell_code_formatter, escape="latex", subset=["selected_features", "dataset", "direction"])
            .to_latex(hrules=True, clines="all;data", convert_css=True, column_format="llccclcclr")
        )

# %% [markdown]
# ### <a id='toc1_1_5_'></a>[Load the results](#toc0_)
#
# Load the previously exported pandas dataframes containing the results of the analysis.

# %%
results_e12gm_pcmci = file_management.load_from_pkl_file(os.path.join(constants.path_table_objects, "results_table_e12gm_pcmci.pkl"))
results_e12gm_te = file_management.load_from_pkl_file(os.path.join(constants.path_table_objects, "results_table_e12gm_te.pkl"))
results_ticino_pcmci = file_management.load_from_pkl_file(os.path.join(constants.path_table_objects, "results_table_ticino_pcmci.pkl"))
results_ticino_te = file_management.load_from_pkl_file(os.path.join(constants.path_table_objects, "results_table_ticino_te.pkl"))

results_e12gm_noCMI_te = file_management.load_from_pkl_file(os.path.join(constants.path_table_objects, "results_table_e12gm_noCMI_te.pkl"))

# %%
from scripts.run_benchmark import baseline

baseline
# Out:
#                                    Emiliani1  Emiliani2  GardaMincio    Ticino
# solo (lag=0)                        0.286071   0.243534     0.171307  0.154807
# solo (lag=0,1)                      0.284043   0.306111     0.191933  0.177646
# solo + extended (lag=0)             0.344448   0.292431     0.185493  0.162634
# solo + extended (lag=0,1)           0.373261   0.292733     0.169552  0.167326
# ar(1)                               0.275232   0.292035     0.289653  0.199807
# ar(1) + solo (lag=0,1)              0.424901   0.432553     0.437795  0.331817
# ar(1) + solo + extended (lag=0,1)   0.468767   0.430417     0.413616  0.330220

# %% [markdown]
# ## <a id='toc1_3_'></a>[Basin: Ticino](#toc0_)

# %% [markdown]
# ### <a id='toc1_3_1_'></a>[Full version](#toc0_)

# %% [markdown]
# #### <a id='toc1_3_1_1_'></a>[PCMCI](#toc0_)

# %%
target_file = os.path.join(constants.path_table_tex, "ticino_pcmci_full.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_results_dataframe_pcmci(results_ticino_pcmci, target_file)
results_ticino_pcmci.style.pipe(make_pcmci_all_pretty)
# Out:
# <style type="text/css">
# #T_167b7_row0_col1, #T_167b7_row0_col2, #T_167b7_row0_col3, #T_167b7_row1_col1, #T_167b7_row1_col2, #T_167b7_row1_col3, #T_167b7_row4_col1, #T_167b7_row4_col2, #T_167b7_row4_col3, #T_167b7_row5_col1, #T_167b7_row5_col2, #T_167b7_row5_col3 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_167b7_row0_col8 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_167b7_row1_col8, #T_167b7_row3_col8, #T_167b7_row5_col8, #T_167b7_row7_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_167b7_row2_col1, #T_167b7_row3_col1, #T_167b7_row6_col1, #T_167b7_row7_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_167b7_row2_col2, #T_167b7_row3_col2, #T_167b7_row6_col2, #T_167b7_row7_col2 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_167b7_row2_col3, #T_167b7_row3_col3, #T_167b7_row6_col3, #T_167b7_row7_col3 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_167b7_row2_col8 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_167b7_row4_col8 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_167b7_row6_col8 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# </style>
# <table id="T_167b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_167b7_level0_col0" class="col_heading level0 col0" >selected_features</th>
#       <th id="T_167b7_level0_col1" class="col_heading level0 col1" >score_r2</th>
#       <th id="T_167b7_level0_col2" class="col_heading level0 col2" >score_r2_lag</th>
#       <th id="T_167b7_level0_col3" class="col_heading level0 col3" >score_r2_lag_ar</th>
#       <th id="T_167b7_level0_col4" class="col_heading level0 col4" >dataset</th>
#       <th id="T_167b7_level0_col5" class="col_heading level0 col5" >algorithm</th>
#       <th id="T_167b7_level0_col6" class="col_heading level0 col6" >independencetest</th>
#       <th id="T_167b7_level0_col7" class="col_heading level0 col7" >lag</th>
#       <th id="T_167b7_level0_col8" class="col_heading level0 col8" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_167b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_167b7_row0_col0" class="data row0 col0" >cyclostationary_mean_tg_0 cyclostationary_mean_rr_4w_0</td>
#       <td id="T_167b7_row0_col1" class="data row0 col1" >0.149</td>
#       <td id="T_167b7_row0_col2" class="data row0 col2" >0.149</td>
#       <td id="T_167b7_row0_col3" class="data row0 col3" >0.149</td>
#       <td id="T_167b7_row0_col4" class="data row0 col4" >normal</td>
#       <td id="T_167b7_row0_col5" class="data row0 col5" >pcmci_plus</td>
#       <td id="T_167b7_row0_col6" class="data row0 col6" >cmiknn</td>
#       <td id="T_167b7_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_167b7_row0_col8" class="data row0 col8" >32.662s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_167b7_row1_col0" class="data row1 col0" >cyclostationary_mean_tg_0 cyclostationary_mean_rr_4w_0</td>
#       <td id="T_167b7_row1_col1" class="data row1 col1" >0.149</td>
#       <td id="T_167b7_row1_col2" class="data row1 col2" >0.149</td>
#       <td id="T_167b7_row1_col3" class="data row1 col3" >0.149</td>
#       <td id="T_167b7_row1_col4" class="data row1 col4" >normal</td>
#       <td id="T_167b7_row1_col5" class="data row1 col5" >pcmci_plus</td>
#       <td id="T_167b7_row1_col6" class="data row1 col6" >parcorr</td>
#       <td id="T_167b7_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_167b7_row1_col8" class="data row1 col8" >0.018s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_167b7_row2_col0" class="data row2 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_167b7_row2_col1" class="data row2 col1" >0.138</td>
#       <td id="T_167b7_row2_col2" class="data row2 col2" >0.188</td>
#       <td id="T_167b7_row2_col3" class="data row2 col3" >0.331</td>
#       <td id="T_167b7_row2_col4" class="data row2 col4" >normal</td>
#       <td id="T_167b7_row2_col5" class="data row2 col5" >pcmci_plus</td>
#       <td id="T_167b7_row2_col6" class="data row2 col6" >cmiknn</td>
#       <td id="T_167b7_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_167b7_row2_col8" class="data row2 col8" >112.996s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_167b7_row3_col0" class="data row3 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_167b7_row3_col1" class="data row3 col1" >0.138</td>
#       <td id="T_167b7_row3_col2" class="data row3 col2" >0.188</td>
#       <td id="T_167b7_row3_col3" class="data row3 col3" >0.331</td>
#       <td id="T_167b7_row3_col4" class="data row3 col4" >normal</td>
#       <td id="T_167b7_row3_col5" class="data row3 col5" >pcmci_plus</td>
#       <td id="T_167b7_row3_col6" class="data row3 col6" >parcorr</td>
#       <td id="T_167b7_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_167b7_row3_col8" class="data row3 col8" >0.069s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_167b7_row4_col0" class="data row4 col0" >cyclostationary_mean_HS_0 cyclostationary_mean_tg_0 cyclostationary_mean_rr_4w_0</td>
#       <td id="T_167b7_row4_col1" class="data row4 col1" >0.149</td>
#       <td id="T_167b7_row4_col2" class="data row4 col2" >0.149</td>
#       <td id="T_167b7_row4_col3" class="data row4 col3" >0.149</td>
#       <td id="T_167b7_row4_col4" class="data row4 col4" >snowlakes</td>
#       <td id="T_167b7_row4_col5" class="data row4 col5" >pcmci_plus</td>
#       <td id="T_167b7_row4_col6" class="data row4 col6" >cmiknn</td>
#       <td id="T_167b7_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_167b7_row4_col8" class="data row4 col8" >264.168s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_167b7_row5_col0" class="data row5 col0" >cyclostationary_mean_tg_0 cyclostationary_mean_rr_4w_0</td>
#       <td id="T_167b7_row5_col1" class="data row5 col1" >0.149</td>
#       <td id="T_167b7_row5_col2" class="data row5 col2" >0.149</td>
#       <td id="T_167b7_row5_col3" class="data row5 col3" >0.149</td>
#       <td id="T_167b7_row5_col4" class="data row5 col4" >snowlakes</td>
#       <td id="T_167b7_row5_col5" class="data row5 col5" >pcmci_plus</td>
#       <td id="T_167b7_row5_col6" class="data row5 col6" >parcorr</td>
#       <td id="T_167b7_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_167b7_row5_col8" class="data row5 col8" >0.146s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_167b7_row6_col0" class="data row6 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_167b7_row6_col1" class="data row6 col1" >0.138</td>
#       <td id="T_167b7_row6_col2" class="data row6 col2" >0.188</td>
#       <td id="T_167b7_row6_col3" class="data row6 col3" >0.331</td>
#       <td id="T_167b7_row6_col4" class="data row6 col4" >snowlakes</td>
#       <td id="T_167b7_row6_col5" class="data row6 col5" >pcmci_plus</td>
#       <td id="T_167b7_row6_col6" class="data row6 col6" >cmiknn</td>
#       <td id="T_167b7_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_167b7_row6_col8" class="data row6 col8" >347.146s</td>
#     </tr>
#     <tr>
#       <th id="T_167b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_167b7_row7_col0" class="data row7 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_167b7_row7_col1" class="data row7 col1" >0.138</td>
#       <td id="T_167b7_row7_col2" class="data row7 col2" >0.188</td>
#       <td id="T_167b7_row7_col3" class="data row7 col3" >0.331</td>
#       <td id="T_167b7_row7_col4" class="data row7 col4" >snowlakes</td>
#       <td id="T_167b7_row7_col5" class="data row7 col5" >pcmci_plus</td>
#       <td id="T_167b7_row7_col6" class="data row7 col6" >parcorr</td>
#       <td id="T_167b7_row7_col7" class="data row7 col7" >1</td>
#       <td id="T_167b7_row7_col8" class="data row7 col8" >0.285s</td>

# %% [markdown]
# #### <a id='toc1_3_1_2_'></a>[TEFS](#toc0_)

# %%
target_file = os.path.join(constants.path_table_tex, "ticino_te_full.tex")
export_results_dataframe_te(results_ticino_te, target_file)
results_ticino_te.style.pipe(make_te_all_pretty)
# Out:
# <style type="text/css">
# #T_356cb_row0_col1, #T_356cb_row0_col2, #T_356cb_row1_col1, #T_356cb_row1_col2, #T_356cb_row2_col1, #T_356cb_row3_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_356cb_row0_col3, #T_356cb_row1_col3 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_356cb_row0_col8, #T_356cb_row1_col8, #T_356cb_row2_col8, #T_356cb_row3_col8, #T_356cb_row4_col8, #T_356cb_row5_col8, #T_356cb_row6_col8, #T_356cb_row7_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_356cb_row2_col2, #T_356cb_row3_col2 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_356cb_row2_col3, #T_356cb_row3_col3 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_356cb_row4_col1, #T_356cb_row4_col2, #T_356cb_row5_col1, #T_356cb_row5_col2, #T_356cb_row7_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_356cb_row4_col3, #T_356cb_row5_col3 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_356cb_row6_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_356cb_row6_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_356cb_row6_col3 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_356cb_row7_col2 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_356cb_row7_col3 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_356cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_356cb_level0_col0" class="col_heading level0 col0" >selected_features</th>
#       <th id="T_356cb_level0_col1" class="col_heading level0 col1" >score_r2</th>
#       <th id="T_356cb_level0_col2" class="col_heading level0 col2" >score_r2_lag</th>
#       <th id="T_356cb_level0_col3" class="col_heading level0 col3" >score_r2_lag_ar</th>
#       <th id="T_356cb_level0_col4" class="col_heading level0 col4" >dataset</th>
#       <th id="T_356cb_level0_col5" class="col_heading level0 col5" >lagfeatures</th>
#       <th id="T_356cb_level0_col6" class="col_heading level0 col6" >lagtarget</th>
#       <th id="T_356cb_level0_col7" class="col_heading level0 col7" >direction</th>
#       <th id="T_356cb_level0_col8" class="col_heading level0 col8" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_356cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_356cb_row0_col0" class="data row0 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row0_col1" class="data row0 col1" >0.138</td>
#       <td id="T_356cb_row0_col2" class="data row0 col2" >0.138</td>
#       <td id="T_356cb_row0_col3" class="data row0 col3" >0.346</td>
#       <td id="T_356cb_row0_col4" class="data row0 col4" >normal</td>
#       <td id="T_356cb_row0_col5" class="data row0 col5" >[0]</td>
#       <td id="T_356cb_row0_col6" class="data row0 col6" >[1]</td>
#       <td id="T_356cb_row0_col7" class="data row0 col7" >backward</td>
#       <td id="T_356cb_row0_col8" class="data row0 col8" >0.401s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_356cb_row1_col0" class="data row1 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row1_col1" class="data row1 col1" >0.138</td>
#       <td id="T_356cb_row1_col2" class="data row1 col2" >0.138</td>
#       <td id="T_356cb_row1_col3" class="data row1 col3" >0.346</td>
#       <td id="T_356cb_row1_col4" class="data row1 col4" >normal</td>
#       <td id="T_356cb_row1_col5" class="data row1 col5" >[0]</td>
#       <td id="T_356cb_row1_col6" class="data row1 col6" >[1]</td>
#       <td id="T_356cb_row1_col7" class="data row1 col7" >forward</td>
#       <td id="T_356cb_row1_col8" class="data row1 col8" >0.372s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_356cb_row2_col0" class="data row2 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row2_col1" class="data row2 col1" >0.138</td>
#       <td id="T_356cb_row2_col2" class="data row2 col2" >0.188</td>
#       <td id="T_356cb_row2_col3" class="data row2 col3" >0.331</td>
#       <td id="T_356cb_row2_col4" class="data row2 col4" >normal</td>
#       <td id="T_356cb_row2_col5" class="data row2 col5" >[0, 1]</td>
#       <td id="T_356cb_row2_col6" class="data row2 col6" >[1]</td>
#       <td id="T_356cb_row2_col7" class="data row2 col7" >backward</td>
#       <td id="T_356cb_row2_col8" class="data row2 col8" >0.415s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_356cb_row3_col0" class="data row3 col0" >cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row3_col1" class="data row3 col1" >0.138</td>
#       <td id="T_356cb_row3_col2" class="data row3 col2" >0.188</td>
#       <td id="T_356cb_row3_col3" class="data row3 col3" >0.331</td>
#       <td id="T_356cb_row3_col4" class="data row3 col4" >normal</td>
#       <td id="T_356cb_row3_col5" class="data row3 col5" >[0, 1]</td>
#       <td id="T_356cb_row3_col6" class="data row3 col6" >[1]</td>
#       <td id="T_356cb_row3_col7" class="data row3 col7" >forward</td>
#       <td id="T_356cb_row3_col8" class="data row3 col8" >0.388s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_356cb_row4_col0" class="data row4 col0" >cyclostat_level_Lugano cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row4_col1" class="data row4 col1" >0.194</td>
#       <td id="T_356cb_row4_col2" class="data row4 col2" >0.194</td>
#       <td id="T_356cb_row4_col3" class="data row4 col3" >0.360</td>
#       <td id="T_356cb_row4_col4" class="data row4 col4" >snowlakes</td>
#       <td id="T_356cb_row4_col5" class="data row4 col5" >[0]</td>
#       <td id="T_356cb_row4_col6" class="data row4 col6" >[1]</td>
#       <td id="T_356cb_row4_col7" class="data row4 col7" >backward</td>
#       <td id="T_356cb_row4_col8" class="data row4 col8" >1.650s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_356cb_row5_col0" class="data row5 col0" >cyclostat_level_Lugano cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row5_col1" class="data row5 col1" >0.194</td>
#       <td id="T_356cb_row5_col2" class="data row5 col2" >0.194</td>
#       <td id="T_356cb_row5_col3" class="data row5 col3" >0.360</td>
#       <td id="T_356cb_row5_col4" class="data row5 col4" >snowlakes</td>
#       <td id="T_356cb_row5_col5" class="data row5 col5" >[0]</td>
#       <td id="T_356cb_row5_col6" class="data row5 col6" >[1]</td>
#       <td id="T_356cb_row5_col7" class="data row5 col7" >forward</td>
#       <td id="T_356cb_row5_col8" class="data row5 col8" >1.612s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_356cb_row6_col0" class="data row6 col0" >cyclostationary_mean_HS_0 cyclostationary_mean_tg_2</td>
#       <td id="T_356cb_row6_col1" class="data row6 col1" >0.067</td>
#       <td id="T_356cb_row6_col2" class="data row6 col2" >0.083</td>
#       <td id="T_356cb_row6_col3" class="data row6 col3" >0.309</td>
#       <td id="T_356cb_row6_col4" class="data row6 col4" >snowlakes</td>
#       <td id="T_356cb_row6_col5" class="data row6 col5" >[0, 1]</td>
#       <td id="T_356cb_row6_col6" class="data row6 col6" >[1]</td>
#       <td id="T_356cb_row6_col7" class="data row6 col7" >backward</td>
#       <td id="T_356cb_row6_col8" class="data row6 col8" >1.777s</td>
#     </tr>
#     <tr>
#       <th id="T_356cb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_356cb_row7_col0" class="data row7 col0" >cyclostat_level_Lugano cyclostationary_mean_tg_0</td>
#       <td id="T_356cb_row7_col1" class="data row7 col1" >0.194</td>
#       <td id="T_356cb_row7_col2" class="data row7 col2" >0.238</td>
#       <td id="T_356cb_row7_col3" class="data row7 col3" >0.345</td>
#       <td id="T_356cb_row7_col4" class="data row7 col4" >snowlakes</td>
#       <td id="T_356cb_row7_col5" class="data row7 col5" >[0, 1]</td>
#       <td id="T_356cb_row7_col6" class="data row7 col6" >[1]</td>
#       <td id="T_356cb_row7_col7" class="data row7 col7" >forwa

# %% [markdown]
# ## <a id='toc1_2_'></a>[Basin: E12GM](#toc0_)

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[Full version](#toc0_)

# %% [markdown]
# #### <a id='toc1_2_1_1_'></a>[PCMCI](#toc0_)

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_pcmci_full.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_results_dataframe_pcmci(results_e12gm_pcmci, target_file)
results_e12gm_pcmci.style.pipe(make_pcmci_all_pretty)
# Out:
# <style type="text/css">
# #T_8d998_row0_col1, #T_8d998_row0_col2, #T_8d998_row0_col3 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_8d998_row0_col8 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_8d998_row1_col1, #T_8d998_row1_col2, #T_8d998_row1_col3 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_8d998_row1_col8, #T_8d998_row3_col8, #T_8d998_row5_col8, #T_8d998_row7_col8, #T_8d998_row9_col8, #T_8d998_row11_col8, #T_8d998_row13_col8, #T_8d998_row15_col8, #T_8d998_row17_col8, #T_8d998_row19_col8, #T_8d998_row21_col8, #T_8d998_row23_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_8d998_row2_col1 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_8d998_row2_col2, #T_8d998_row5_col1, #T_8d998_row5_col2, #T_8d998_row5_col3 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_8d998_row2_col3 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_8d998_row2_col8 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_8d998_row3_col1 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_8d998_row3_col2 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_8d998_row3_col3 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_8d998_row4_col1, #T_8d998_row4_col2, #T_8d998_row4_col3 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_8d998_row4_col8 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_8d998_row6_col1, #T_8d998_row7_col1 {
#   background-color: #b7e2b1;
#   color: #000000;
# }
# #T_8d998_row6_col2, #T_8d998_row7_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_8d998_row6_col3, #T_8d998_row7_col3 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_8d998_row6_col8 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_8d998_row8_col1, #T_8d998_row8_col2, #T_8d998_row8_col3, #T_8d998_row11_col1 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_8d998_row8_col8 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_8d998_row9_col1, #T_8d998_row9_col2, #T_8d998_row9_col3, #T_8d998_row10_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_8d998_row10_col2 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_8d998_row10_col3 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_8d998_row10_col8 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_8d998_row11_col2 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_8d998_row11_col3 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_8d998_row12_col1, #T_8d998_row12_col2, #T_8d998_row12_col3 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_8d998_row12_col8 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_8d998_row13_col1, #T_8d998_row13_col2, #T_8d998_row13_col3 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_8d998_row14_col1, #T_8d998_row15_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_8d998_row14_col2, #T_8d998_row15_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_8d998_row14_col3, #T_8d998_row15_col3 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_8d998_row14_col8 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_8d998_row16_col1, #T_8d998_row16_col2, #T_8d998_row16_col3, #T_8d998_row17_col1, #T_8d998_row17_col2, #T_8d998_row17_col3, #T_8d998_row18_col1, #T_8d998_row19_col1 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_8d998_row16_col8 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_8d998_row18_col2, #T_8d998_row19_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_8d998_row18_col3, #T_8d998_row19_col3 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_8d998_row18_col8 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_8d998_row20_col1, #T_8d998_row20_col2, #T_8d998_row20_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_8d998_row20_col8 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_8d998_row21_col1, #T_8d998_row21_col2, #T_8d998_row21_col3, #T_8d998_row22_col1, #T_8d998_row23_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_8d998_row22_col2, #T_8d998_row23_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_8d998_row22_col3, #T_8d998_row23_col3 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_8d998_row22_col8 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8d998">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d998_level0_col0" class="col_heading level0 col0" >selected_features</th>
#       <th id="T_8d998_level0_col1" class="col_heading level0 col1" >score_r2</th>
#       <th id="T_8d998_level0_col2" class="col_heading level0 col2" >score_r2_lag</th>
#       <th id="T_8d998_level0_col3" class="col_heading level0 col3" >score_r2_lag_ar</th>
#       <th id="T_8d998_level0_col4" class="col_heading level0 col4" >dataset</th>
#       <th id="T_8d998_level0_col5" class="col_heading level0 col5" >algorithm</th>
#       <th id="T_8d998_level0_col6" class="col_heading level0 col6" >independencetest</th>
#       <th id="T_8d998_level0_col7" class="col_heading level0 col7" >lag</th>
#       <th id="T_8d998_level0_col8" class="col_heading level0 col8" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d998_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d998_row0_col0" class="data row0 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_1w_16 E1cyclostationary_mean_rr_24w_2</td>
#       <td id="T_8d998_row0_col1" class="data row0 col1" >0.286</td>
#       <td id="T_8d998_row0_col2" class="data row0 col2" >0.286</td>
#       <td id="T_8d998_row0_col3" class="data row0 col3" >0.286</td>
#       <td id="T_8d998_row0_col4" class="data row0 col4" >df_E1</td>
#       <td id="T_8d998_row0_col5" class="data row0 col5" >pcmci_plus</td>
#       <td id="T_8d998_row0_col6" class="data row0 col6" >cmiknn</td>
#       <td id="T_8d998_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_8d998_row0_col8" class="data row0 col8" >384.152s</td>
#     </tr>
#     <tr>
#       <th id="T_8d998_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d998_row1_col0" class="data row1 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_24w_2</td>
#       <td id="T_8d998_row1_col1" class="data row1 col1" >0.289</td>
#       <td id="T_8d998_row1_col2" class="data row1 col2" >0.289</td>
#       <td id="T_8d998_row1_col3" class="data row1 col3" >0.289</td>
#       <td id="T_8d998_row1_col4" class="data row1 col4" >df_E1</td>
#       <td id="T_8d998_row1_col5" class="data row1 col5" >pcmci_plus</td>
#       <td id="T_8d998_row1_col6" class="data row1 col6" >parcorr</td>
#       <td id="T_8d998_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_8d998_row1_col8" class="data row1 col8" >0.046s</td>
#     </tr>
#     <tr>
#       <th id="T_8d998_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d998_row2_col0" class="data row2 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_1w_16</td>
#       <td id="T_8d998_row2_col1" class="data row2 col1" >0.251</td>
#       <td id="T_8d998_row2_col2" class="data row2 col2" >0.255</td>
#       <td id="T_8d998_row2_col3" class="data row2 col3" >0.420</td>
#       <td id="T_8d998_row2_col4" class="data row2 col4" >df_E1</td>
#       <td id="T_8d998_row2_col5" class="data row2 col5" >pcmci_plus</td>
#       <td id="T_8d998_row2_col6" class="data row2 col6" >cmiknn</td>
#       <td id="T_8d998_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_8d998_row2_col8" class="data row2 col8" >1308.914s</td>
#     </tr>
#     <tr>
#       <th id="T_8d998_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d998_row3_col0" class="data row3 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0</td>
#       <td id="T_8d998_row3_col1" class="data row3 col1" >0.257</td>
#       <td id="T_8d998_row3_col2" class="data row3 col2" >0.265</td>
#       <td id="T_8d998_row3_col3" class="data row3 col3" >0.421</td>
#       <td id="T_8d998_row3_col4" class="data row3 col4" >df_E1</td>
#       <td id="T_8d998_row3_col5" class="data row3 col5" >pcmci

# %% [markdown]
# #### <a id='toc1_2_1_2_'></a>[TEFS](#toc0_)

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_te_full.tex")
export_results_dataframe_te(results_e12gm_te, target_file)
results_e12gm_te.style.pipe(make_te_all_pretty)
# Out:
# <style type="text/css">
# #T_ce4d1_row0_col1, #T_ce4d1_row0_col2, #T_ce4d1_row1_col1, #T_ce4d1_row1_col2, #T_ce4d1_row5_col1, #T_ce4d1_row5_col2 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_ce4d1_row0_col3, #T_ce4d1_row1_col3, #T_ce4d1_row5_col3 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_ce4d1_row0_col8, #T_ce4d1_row1_col8, #T_ce4d1_row2_col8, #T_ce4d1_row3_col8, #T_ce4d1_row4_col8, #T_ce4d1_row5_col8, #T_ce4d1_row6_col8, #T_ce4d1_row7_col8, #T_ce4d1_row8_col8, #T_ce4d1_row9_col8, #T_ce4d1_row10_col8, #T_ce4d1_row11_col8, #T_ce4d1_row12_col8, #T_ce4d1_row13_col8, #T_ce4d1_row14_col8, #T_ce4d1_row15_col8, #T_ce4d1_row16_col8, #T_ce4d1_row17_col8, #T_ce4d1_row18_col8, #T_ce4d1_row19_col8, #T_ce4d1_row20_col8, #T_ce4d1_row21_col8, #T_ce4d1_row22_col8, #T_ce4d1_row23_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ce4d1_row2_col1, #T_ce4d1_row3_col1, #T_ce4d1_row6_col1, #T_ce4d1_row7_col1 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_ce4d1_row2_col2, #T_ce4d1_row3_col2, #T_ce4d1_row6_col2, #T_ce4d1_row7_col2 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_ce4d1_row2_col3, #T_ce4d1_row3_col3, #T_ce4d1_row6_col3, #T_ce4d1_row7_col3, #T_ce4d1_row15_col3 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_ce4d1_row4_col1, #T_ce4d1_row4_col2 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_ce4d1_row4_col3 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_ce4d1_row8_col1, #T_ce4d1_row8_col2, #T_ce4d1_row9_col1, #T_ce4d1_row9_col2, #T_ce4d1_row12_col1, #T_ce4d1_row12_col2, #T_ce4d1_row13_col1, #T_ce4d1_row13_col2 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_ce4d1_row8_col3, #T_ce4d1_row9_col3, #T_ce4d1_row12_col3, #T_ce4d1_row13_col3 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_ce4d1_row10_col1, #T_ce4d1_row11_col1, #T_ce4d1_row14_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_ce4d1_row10_col2, #T_ce4d1_row11_col2, #T_ce4d1_row14_col2, #T_ce4d1_row15_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_ce4d1_row10_col3, #T_ce4d1_row11_col3, #T_ce4d1_row14_col3, #T_ce4d1_row21_col3 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_ce4d1_row15_col1 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_ce4d1_row16_col1, #T_ce4d1_row16_col2, #T_ce4d1_row17_col1, #T_ce4d1_row17_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_ce4d1_row16_col3, #T_ce4d1_row17_col3 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_ce4d1_row18_col1, #T_ce4d1_row19_col1, #T_ce4d1_row23_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_ce4d1_row18_col2, #T_ce4d1_row19_col2, #T_ce4d1_row23_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_ce4d1_row18_col3, #T_ce4d1_row19_col3, #T_ce4d1_row23_col3 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_ce4d1_row20_col1, #T_ce4d1_row20_col2 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_ce4d1_row20_col3 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_ce4d1_row21_col1, #T_ce4d1_row21_col2 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_ce4d1_row22_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_ce4d1_row22_col2 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_ce4d1_row22_col3 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce4d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce4d1_level0_col0" class="col_heading level0 col0" >selected_features</th>
#       <th id="T_ce4d1_level0_col1" class="col_heading level0 col1" >score_r2</th>
#       <th id="T_ce4d1_level0_col2" class="col_heading level0 col2" >score_r2_lag</th>
#       <th id="T_ce4d1_level0_col3" class="col_heading level0 col3" >score_r2_lag_ar</th>
#       <th id="T_ce4d1_level0_col4" class="col_heading level0 col4" >dataset</th>
#       <th id="T_ce4d1_level0_col5" class="col_heading level0 col5" >lagfeatures</th>
#       <th id="T_ce4d1_level0_col6" class="col_heading level0 col6" >lagtarget</th>
#       <th id="T_ce4d1_level0_col7" class="col_heading level0 col7" >direction</th>
#       <th id="T_ce4d1_level0_col8" class="col_heading level0 col8" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce4d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce4d1_row0_col0" class="data row0 col0" >E1cyclostationary_mean_rr_1w_16 E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0</td>
#       <td id="T_ce4d1_row0_col1" class="data row0 col1" >0.251</td>
#       <td id="T_ce4d1_row0_col2" class="data row0 col2" >0.251</td>
#       <td id="T_ce4d1_row0_col3" class="data row0 col3" >0.457</td>
#       <td id="T_ce4d1_row0_col4" class="data row0 col4" >df_E1</td>
#       <td id="T_ce4d1_row0_col5" class="data row0 col5" >[0]</td>
#       <td id="T_ce4d1_row0_col6" class="data row0 col6" >[1]</td>
#       <td id="T_ce4d1_row0_col7" class="data row0 col7" >backward</td>
#       <td id="T_ce4d1_row0_col8" class="data row0 col8" >0.688s</td>
#     </tr>
#     <tr>
#       <th id="T_ce4d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce4d1_row1_col0" class="data row1 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_1w_16</td>
#       <td id="T_ce4d1_row1_col1" class="data row1 col1" >0.251</td>
#       <td id="T_ce4d1_row1_col2" class="data row1 col2" >0.251</td>
#       <td id="T_ce4d1_row1_col3" class="data row1 col3" >0.457</td>
#       <td id="T_ce4d1_row1_col4" class="data row1 col4" >df_E1</td>
#       <td id="T_ce4d1_row1_col5" class="data row1 col5" >[0]</td>
#       <td id="T_ce4d1_row1_col6" class="data row1 col6" >[1]</td>
#       <td id="T_ce4d1_row1_col7" class="data row1 col7" >forward</td>
#       <td id="T_ce4d1_row1_col8" class="data row1 col8" >0.633s</td>
#     </tr>
#     <tr>
#       <th id="T_ce4d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce4d1_row2_col0" class="data row2 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0</td>
#       <td id="T_ce4d1_row2_col1" class="data row2 col1" >0.257</td>
#       <td id="T_ce4d1_row2_col2" class="data row2 col2" >0.265</td>
#       <td id="T_ce4d1_row2_col3" class="data row2 col3" >0.421</td>
#       <td id="T_ce4d1_row2_col4" class="data row2 col4" >df_E1</td>
#       <td id="T_ce4d1_row2_col5" class="data row2 col5" >[0, 1]</td>
#       <td id="T_ce4d1_row2_col6" class="data row2 col6" >[1]</td>
#       <td id="T_ce4d1_row2_col7" class="data row2 col7" >backward</td>
#       <td id="T_ce4d1_row2_col8" class="data row2 col8" >0.757s</td>
#     </tr>
#     <tr>
#       <th id="T_ce4d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce4d1_row3_col0" class="data row3 col0" >E1cyclostationary_mean_rr_4w_1 E1cyclostationary_mean_tg_0</td>
#       <td id="T_ce4d1_row3_col1" class="data row3 col1" >0.257</td>
#       <td id="T_ce4d1_row3_col2" class="data row3 col2" >0.265</td>
#       <td id="T_ce4d1_row3_col3" class="data row3 col3" >0.421</td>
#       <td id="T_ce4d1_row3_col4" class="data row3 col4" >df_E1</td>
#       <td id="T_ce4d1_row3_col5" class="data row3 col5" >[0, 1]</td>
#       <td id="T_ce4d1_row3_col6" class="data row3 col6" >[1]</td>
#       <td id="T_ce4d1_row3_col7" class="data row3 col7" >forward</td>
#       <td id="T_ce4d1_row3_col8" class="data row3 col8" >0.659s</td>
#     </tr>
#     <tr>
#       <th id="T_ce4d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce4d1_row4_col0" class="data row4 col0" >GMcyclostationary_mean_tg_1w_0 E2cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_4w_1</td>
#       <td id="T_ce4d1_row4_col1" class="data row4 col1" >0.231</td>
#       <td id="T_ce4d1_row4_col2" class="data row4 col2" >0.231</td>
#       <td id="T_ce4d1_row4_col3" class="data row4 col3" >0.405</td>
#       <td id="T_ce4d1_row4_col4" class="data row4 col4" >df_E1allfeatures</td>
#       <td id="T_ce4d1_row4_col5" class="data row4 col5" >[0]</td>
#       <td id="T_ce4d1_row4_col6" class="data row4 col6" >[1]</td>
#       <td id="T_ce4d1_row4_col7" class="data row4 col7" >backward</td>
#       <td id="T_ce4d1_row4_col8"

# %% [markdown]
# ### <a id='toc1_2_2_'></a>[Summarized version](#toc0_)

# %% [markdown]
# #### <a id='toc1_2_2_1_'></a>[PCMCI](#toc0_)

# %%
results_e12gm_pcmci
# Out:
#                                     selected_features  score_r2  score_r2_lag  \
# 0   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.286071      0.286071
# 1   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.289250      0.289250
# 2   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.251060      0.255466
# 3   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.256639      0.265190
# 4   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.181424      0.181424
# 5   E1cyclostationary_mean_rr_4w_1 E1cyclostationa...  0.254281      0.254281
# 6                      E1cyclostationary_mean_rr_4w_1  0.150558      0.147686
# 7                      E1cyclostationary_mean_rr_4w_1  0.150558      0.147686
# 8   E2cyclostationary_mean_tg_0 E2cyclostationary_...  0.230389      0.230389
# 9   E2cyclostationary_mean_tg_0 E2cyclostationary_...  0.221522      0.221522
# 10  E2cyclostationary_mean_tg_0 E2cyclostationary_...  0.221522      0.239127
# 11  E2cyclostationary_mean_tg_0 E2cyclostationary_...  0.230389      0.248450
# 12  E1cyclostationary_mean_rr_24w_2 E2cyclostation...  0.297771      0.297771
# 13  E1cyclostationary_mean_rr_4w_1 E2cyclostationa...  0.191082      0.191082
# 14                        E2cyclostationary_mean_tg_0  0.111514      0.146193
# 15                        E2cyclostationary_mean_tg_0  0.111514      0.146193
# 16  GMcyclostationary_mean_tg_1w_0 GMcyclostationa...  0.176563      0.176563
# 17  GMcyclostationary_mean_tg_1w_0 GMcyclostationa...  0.176563      0.176563
# 18  GMcyclostationary_mean_tg_1w_0 GMcyclostationa...  0.176563      0.203489
# 19  GMcyclostationary_mean_tg_1w_0 GMcyclostationa...  0.176563      0.203489
# 20  E1cyclostationary_mean_rr_1w_16 E1cyclostation...  0.087925      0.087925
# 21  E1cyclostationary_mean_rr_4w_1 E2cyclostationa...  0.109771      0.109771
# 22  E1cyclostationary_mean_rr_4w_1 E2cyclostationa...  0.109771      0.119979
# 23  E1cyclostationary_mean_rr_4w_1 E2cyclostationa...  0.109771      0.119979
#
#     score_r2_lag_ar           dataset   algorithm independencetest  lag  \
# 0          0.286071             df_E1  pcmci_plus           cmiknn    0
# 1          0.289250             df_E1  pcmci_plus          parcorr    0
# 2          0.419614             df_E1  pcmci_plus           cmiknn    1
# 3          0.420932             df_E1  pcmci_plus          parcorr    1
# 4          0.181424  df_E1allfeatures  pcmci_plus           cmiknn    0
# 5          0.254281  df_E1allfeatures  pcmci_plus          parcorr    0
# 6          0.367535  df_E1allfeatures  pcmci_plus           cmiknn    1
# 7          0.367535  df_E1allfeatures  pcmci_plus          parcorr    1
# 8          0.230389             df_E2  pcmci_plus           cmiknn    0
# 9          0.221522             df_E2  pcmci_plus          parcorr    0
# 10         0.415827             df_E2  pcmci_plus           cmiknn    1
# 11         0.401565             df_E2  pcmci_plus          parcorr    1
# 12         0.297771  df_E2allfeatures  pcmci_plus           cmiknn    0
# 13         0.191082  df_E2allfeatures  pcmci_plus          parcorr    0
# 14         0.390651  df_E2allfeatures  pcmci_plus           cmiknn    1
# 15         0.390651  df_E2allfeatures  pcmci_plus          parcorr    1
# 16         0.176563             df_GM  pcmci_plus           cmiknn    0
# 17         0.176563             df_GM  pcmci_plus          parcorr    0
# 18         0.442869             df_GM  pcmci_plus           cmiknn    1
# 19         0.442869             df_GM  pcmci_plus          parcorr    1
# 20         0.087925  df_GMallfeatures  pcmci_plus           cmiknn    0
# 21         0.109771  df_GMallfeatures  pcmci_plus          parcorr    0
# 22         0.406443  df_GMallfeatures  pcmci_plus           cmiknn    1
# 23         0.406443  df_GMallfeatures  pcmci_plus          parcorr    1
#
#     execution_time
# 0       384.151514
# 1         0.045593
# 2      1308.913636
# 3         0.274470
# 4      5532.617838
# 5         0.678409
# 6      7726.128555
# 7        10.818769
# 8       810.720993
# 9         0.057513
# 10     1596.576730
# 11        0.314501
# 12     5081.931851
# 13        0.341040
# 14     5268.378825
# 15        8.094075
# 16       87.160898
# 17        0.016086
# 18      504.895575
# 19        0.089332
# 20     1826.917106
# 21        0.345339
# 22     4688.384780
# 23        9.835356

# %%
results_e12gm_pcmci["features_lag"] = results_e12gm_pcmci["lag"].map(
    {
        0: "contemporary",
        1: "contemporary + 1-lagged",
    }
)
results_e12gm_pcmci["features_set"] = results_e12gm_pcmci["dataset"].apply(lambda x: "all" if "all" in x else "single")

results_e12gm_pcmci["dataset"] = results_e12gm_pcmci["dataset"].apply(lambda x: x[3:5])

results_e12gm_pcmci = results_e12gm_pcmci\
    .drop(columns=["selected_features", "algorithm", "lag", "score_r2"])\
    .set_index(["dataset", "independencetest", "features_lag", "features_set"])\
    .unstack("features_set").sort_index(axis=1, ascending=False)  # fmt: off

results_e12gm_pcmci
# Out:
#                                                  score_r2_lag_ar            \
# features_set                                              single       all
# dataset independencetest features_lag
# E1      cmiknn           contemporary                   0.286071  0.181424
#                          contemporary + 1-lagged        0.419614  0.367535
#         parcorr          contemporary                   0.289250  0.254281
#                          contemporary + 1-lagged        0.420932  0.367535
# E2      cmiknn           contemporary                   0.230389  0.297771
#                          contemporary + 1-lagged        0.415827  0.390651
#         parcorr          contemporary                   0.221522  0.191082
#                          contemporary + 1-lagged        0.401565  0.390651
# GM      cmiknn           contemporary                   0.176563  0.087925
#                          contemporary + 1-lagged        0.442869  0.406443
#         parcorr          contemporary                   0.176563  0.109771
#                          contemporary + 1-lagged        0.442869  0.406443
#
#                                                  score_r2_lag            \
# features_set                                           single       all
# dataset independencetest features_lag
# E1      cmiknn           contemporary                0.286071  0.181424
#                          contemporary + 1-lagged     0.255466  0.147686
#         parcorr          contemporary                0.289250  0.254281
#                          contemporary + 1-lagged     0.265190  0.147686
# E2      cmiknn           contemporary                0.230389  0.297771
#                          contemporary + 1-lagged     0.239127  0.146193
#         parcorr          contemporary                0.221522  0.191082
#                          contemporary + 1-lagged     0.248450  0.146193
# GM      cmiknn           contemporary                0.176563  0.087925
#                          contemporary + 1-lagged     0.203489  0.119979
#         parcorr          contemporary                0.176563  0.109771
#                          contemporary + 1-lagged     0.203489  0.119979
#
#                                                  execution_time
# features_set                                             single          all
# dataset independencetest features_lag
# E1      cmiknn           contemporary                384.151514  5532.617838
#                          contemporary + 1-lagged    1308.913636  7726.128555
#         parcorr          contemporary                  0.045593     0.678409
#                          contemporary + 1-lagged       0.274470    10.818769
# E2      cmiknn           contemporary                810.720993  5081.931851
#                          contemporary + 1-lagged    1596.576730  5268.378825
#         parcorr          contemporary                  0.057513     0.341040
#                          contemporary + 1-lagged       0.314501     8.094075
# GM      cmiknn           contemporary                 87.160898  1826.917106
#                          contemporary + 1-lagged     504.895575  4688.384780
#         parcorr          contemporary                  0.016086     0.345339
#                          contemporary + 1-lagged       0.089332     9.835356

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_E1_pcmci.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_pcmci_df_to_latex(results_e12gm_pcmci.iloc[:4, :], target_file)
results_e12gm_pcmci.iloc[:4, :].style.pipe(make_pcmci_pretty)
# Out:
# <style type="text/css">
# #T_5eec4_row0_col0, #T_5eec4_row0_col2 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_5eec4_row0_col1, #T_5eec4_row0_col3 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_5eec4_row0_col4 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_5eec4_row0_col5 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_5eec4_row1_col0 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_5eec4_row1_col1, #T_5eec4_row3_col1 {
#   background-color: #268e47;
#   color: #f1f1f1;
# }
# #T_5eec4_row1_col2, #T_5eec4_row2_col1, #T_5eec4_row2_col3 {
#   background-color: #70c274;
#   color: #000000;
# }
# #T_5eec4_row1_col3, #T_5eec4_row3_col3 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_5eec4_row1_col4 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_5eec4_row1_col5 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_5eec4_row2_col0, #T_5eec4_row2_col2 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_5eec4_row2_col4, #T_5eec4_row2_col5, #T_5eec4_row3_col4, #T_5eec4_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_5eec4_row3_col0 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_5eec4_row3_col2 {
#   background-color: #68be70;
#   color: #000000;
# }
# </style>
# <table id="T_5eec4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5eec4_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_5eec4_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_5eec4_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_5eec4_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_5eec4_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_5eec4_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_5eec4_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_5eec4_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_5eec4_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >independencetest</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5eec4_level0_row0" class="row_heading level0 row0" rowspan="4">E1</th>
#       <th id="T_5eec4_level1_row0" class="row_heading level1 row0" rowspan="2">cmiknn</th>
#       <th id="T_5eec4_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_5eec4_row0_col0" class="data row0 col0" >0.286</td>
#       <td id="T_5eec4_row0_col1" class="data row0 col1" >0.181</td>
#       <td id="T_5eec4_row0_col2" class="data row0 col2" >0.286</td>
#       <td id="T_5eec4_row0_col3" class="data row0 col3" >0.181</td>
#       <td id="T_5eec4_row0_col4" class="data row0 col4" >384.15</td>
#       <td id="T_5eec4_row0_col5" class="data row0 col5" >5532.62</td>
#     </tr>
#     <tr>
#       <th id="T_5eec4_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_5eec4_row1_col0" class="data row1 col0" >0.420</td>
#       <td id="T_5eec4_row1_col1" class="data row1 col1" >0.368</td>
#       <td id="T_5eec4_row1_col2" class="data row1 col2" >0.255</td>
#       <td id="T_5eec4_row1_col3" class="data row1 col3" >0.148</td>
#       <td id="T_5eec4_row1_col4" class="data row1 col4" >1308.91</td>
#       <td id="T_5eec4_row1_col5" class="data row1 col5" >7726.13</td>
#     </tr>
#     <tr>
#       <th id="T_5eec4_level1_row2" class="row_heading level1 row2" rowspan="2">parcorr</th>
#       <th id="T_5eec4_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_5eec4_row2_col0" class="data row2 col0" >0.289</td>
#       <td id="T_5eec4_row2_col1" class="data row2 col1" >0.254</td>
#       <td id="T_5eec4_row2_col2" class="data row2 col2" >0.289</td>
#       <td id="T_5eec4_row2_col3" class="data row2 col3" >0.254</td>
#       <td id="T_5eec4_row2_col4" class="data row2 col4" >0.05</td>
#       <td id="T_5eec4_row2_col5" class="data row2 col5" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_5eec4_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_5eec4_row3_col0" class="data row3 col0" >0.421</td>
#       <td id="T_5eec4_row3_col1" class="data row3 col1" >0.368</td>
#       <td id="T_5eec4_row3_col2" class="data row3 col2" >0.265</td>
#       <td id="T_5eec4_row3_col3" class="data row3 col3" >0.148</td>
#       <td id="T_5eec4_row3_col4" class="data row3 col4" >0.27</td>
#       <td id="T_5eec4_row3_col5" class="data row3 col5" >10.82</td>
#     </tr>
#   </tbody>
# </table>

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_E2_pcmci.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_pcmci_df_to_latex(results_e12gm_pcmci.iloc[4:8, :], target_file)
results_e12gm_pcmci.iloc[4:8, :].style.pipe(make_pcmci_pretty)
# Out:
# <style type="text/css">
# #T_451db_row0_col0, #T_451db_row0_col2 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_451db_row0_col1, #T_451db_row0_col3 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_451db_row0_col4 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_451db_row0_col5 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_451db_row1_col0 {
#   background-color: #0c7735;
#   color: #f1f1f1;
# }
# #T_451db_row1_col1, #T_451db_row3_col1 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_451db_row1_col2 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_451db_row1_col3, #T_451db_row3_col3 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_451db_row1_col4 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_451db_row1_col5 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_451db_row2_col0, #T_451db_row2_col2 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_451db_row2_col1, #T_451db_row2_col3 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_451db_row2_col4, #T_451db_row2_col5, #T_451db_row3_col4, #T_451db_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_451db_row3_col0 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_451db_row3_col2 {
#   background-color: #75c477;
#   color: #000000;
# }
# </style>
# <table id="T_451db">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_451db_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_451db_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_451db_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_451db_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_451db_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_451db_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_451db_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_451db_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_451db_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >independencetest</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_451db_level0_row0" class="row_heading level0 row0" rowspan="4">E2</th>
#       <th id="T_451db_level1_row0" class="row_heading level1 row0" rowspan="2">cmiknn</th>
#       <th id="T_451db_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_451db_row0_col0" class="data row0 col0" >0.230</td>
#       <td id="T_451db_row0_col1" class="data row0 col1" >0.298</td>
#       <td id="T_451db_row0_col2" class="data row0 col2" >0.230</td>
#       <td id="T_451db_row0_col3" class="data row0 col3" >0.298</td>
#       <td id="T_451db_row0_col4" class="data row0 col4" >810.72</td>
#       <td id="T_451db_row0_col5" class="data row0 col5" >5081.93</td>
#     </tr>
#     <tr>
#       <th id="T_451db_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_451db_row1_col0" class="data row1 col0" >0.416</td>
#       <td id="T_451db_row1_col1" class="data row1 col1" >0.391</td>
#       <td id="T_451db_row1_col2" class="data row1 col2" >0.239</td>
#       <td id="T_451db_row1_col3" class="data row1 col3" >0.146</td>
#       <td id="T_451db_row1_col4" class="data row1 col4" >1596.58</td>
#       <td id="T_451db_row1_col5" class="data row1 col5" >5268.38</td>
#     </tr>
#     <tr>
#       <th id="T_451db_level1_row2" class="row_heading level1 row2" rowspan="2">parcorr</th>
#       <th id="T_451db_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_451db_row2_col0" class="data row2 col0" >0.222</td>
#       <td id="T_451db_row2_col1" class="data row2 col1" >0.191</td>
#       <td id="T_451db_row2_col2" class="data row2 col2" >0.222</td>
#       <td id="T_451db_row2_col3" class="data row2 col3" >0.191</td>
#       <td id="T_451db_row2_col4" class="data row2 col4" >0.06</td>
#       <td id="T_451db_row2_col5" class="data row2 col5" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_451db_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_451db_row3_col0" class="data row3 col0" >0.402</td>
#       <td id="T_451db_row3_col1" class="data row3 col1" >0.391</td>
#       <td id="T_451db_row3_col2" class="data row3 col2" >0.248</td>
#       <td id="T_451db_row3_col3" class="data row3 col3" >0.146</td>
#       <td id="T_451db_row3_col4" class="data row3 col4" >0.31</td>
#       <td id="T_451db_row3_col5" class="data row3 col5" >8.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_GM_pcmci.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_pcmci_df_to_latex(results_e12gm_pcmci.iloc[8:, :], target_file)
results_e12gm_pcmci.iloc[8:, :].style.pipe(make_pcmci_pretty)
# Out:
# <style type="text/css">
# #T_9f0f4_row0_col0, #T_9f0f4_row0_col2, #T_9f0f4_row2_col0, #T_9f0f4_row2_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_9f0f4_row0_col1, #T_9f0f4_row0_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_9f0f4_row0_col4 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_9f0f4_row0_col5 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_9f0f4_row1_col0, #T_9f0f4_row3_col0 {
#   background-color: #00692a;
#   color: #f1f1f1;
# }
# #T_9f0f4_row1_col1, #T_9f0f4_row3_col1 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_9f0f4_row1_col2, #T_9f0f4_row3_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_9f0f4_row1_col3, #T_9f0f4_row3_col3 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_9f0f4_row1_col4 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_9f0f4_row1_col5 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_9f0f4_row2_col1, #T_9f0f4_row2_col3 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_9f0f4_row2_col4, #T_9f0f4_row2_col5, #T_9f0f4_row3_col4, #T_9f0f4_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_9f0f4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f0f4_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_9f0f4_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_9f0f4_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_9f0f4_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_9f0f4_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_9f0f4_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_9f0f4_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_9f0f4_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_9f0f4_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >independencetest</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f0f4_level0_row0" class="row_heading level0 row0" rowspan="4">GM</th>
#       <th id="T_9f0f4_level1_row0" class="row_heading level1 row0" rowspan="2">cmiknn</th>
#       <th id="T_9f0f4_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_9f0f4_row0_col0" class="data row0 col0" >0.177</td>
#       <td id="T_9f0f4_row0_col1" class="data row0 col1" >0.088</td>
#       <td id="T_9f0f4_row0_col2" class="data row0 col2" >0.177</td>
#       <td id="T_9f0f4_row0_col3" class="data row0 col3" >0.088</td>
#       <td id="T_9f0f4_row0_col4" class="data row0 col4" >87.16</td>
#       <td id="T_9f0f4_row0_col5" class="data row0 col5" >1826.92</td>
#     </tr>
#     <tr>
#       <th id="T_9f0f4_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_9f0f4_row1_col0" class="data row1 col0" >0.443</td>
#       <td id="T_9f0f4_row1_col1" class="data row1 col1" >0.406</td>
#       <td id="T_9f0f4_row1_col2" class="data row1 col2" >0.203</td>
#       <td id="T_9f0f4_row1_col3" class="data row1 col3" >0.120</td>
#       <td id="T_9f0f4_row1_col4" class="data row1 col4" >504.90</td>
#       <td id="T_9f0f4_row1_col5" class="data row1 col5" >4688.38</td>
#     </tr>
#     <tr>
#       <th id="T_9f0f4_level1_row2" class="row_heading level1 row2" rowspan="2">parcorr</th>
#       <th id="T_9f0f4_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_9f0f4_row2_col0" class="data row2 col0" >0.177</td>
#       <td id="T_9f0f4_row2_col1" class="data row2 col1" >0.110</td>
#       <td id="T_9f0f4_row2_col2" class="data row2 col2" >0.177</td>
#       <td id="T_9f0f4_row2_col3" class="data row2 col3" >0.110</td>
#       <td id="T_9f0f4_row2_col4" class="data row2 col4" >0.02</td>
#       <td id="T_9f0f4_row2_col5" class="data row2 col5" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_9f0f4_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_9f0f4_row3_col0" class="data row3 col0" >0.443</td>
#       <td id="T_9f0f4_row3_col1" class="data row3 col1" >0.406</td>
#       <td id="T_9f0f4_row3_col2" class="data row3 col2" >0.203</td>
#       <td id="T_9f0f4_row3_col3" class="data row3 col3" >0.120</td>
#       <td id="T_9f0f4_row3_col4" class="data row3 col4" >0.09</td>
#       <td id="T_9f0f4_row3_col5" class="data row3 col5" >9.84</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <a id='toc1_2_2_2_'></a>[TEFS](#toc0_)

# %%
def check_list(cell):
    if cell == [0]:
        return "contemporary"
    elif cell == [0, 1]:
        return "contemporary + 1-lagged"

results_e12gm_te["features_lag"] = results_e12gm_te["lagfeatures"].apply(check_list)

# %%
results_e12gm_te["features_set"] = results_e12gm_te["dataset"].apply(lambda x: "all" if "all" in x else "single")
# df_e12gm_te["CMI"] = df_e12gm_te["dataset"].apply(lambda x: "noCMI" if "noCMI" in x else "yesCMI")
results_e12gm_te["dataset"] = results_e12gm_te["dataset"].apply(lambda x: x[3:5])

results_e12gm_te = results_e12gm_te\
    .drop(columns=["selected_features", "lagtarget", "lagfeatures", "score_r2"])\
    .set_index(["dataset", "direction", "features_lag", "features_set"])\
    .unstack("features_set").sort_index(axis=1, ascending=False)  # fmt: off

results_e12gm_te
# Out:
#                                           score_r2_lag_ar            \
# features_set                                       single       all
# dataset direction features_lag
# E1      backward  contemporary                   0.456840  0.405068
#                   contemporary + 1-lagged        0.420932  0.420932
#         forward   contemporary                   0.456840  0.456840
#                   contemporary + 1-lagged        0.420932  0.420932
# E2      backward  contemporary                   0.423374  0.423374
#                   contemporary + 1-lagged        0.390651  0.390651
#         forward   contemporary                   0.423374  0.423374
#                   contemporary + 1-lagged        0.390651  0.421809
# GM      backward  contemporary                   0.359131  0.457228
#                   contemporary + 1-lagged        0.410581  0.376746
#         forward   contemporary                   0.359131  0.391654
#                   contemporary + 1-lagged        0.410581  0.410581
#
#                                           score_r2_lag            \
# features_set                                    single       all
# dataset direction features_lag
# E1      backward  contemporary                0.251060  0.231462
#                   contemporary + 1-lagged     0.265190  0.265190
#         forward   contemporary                0.251060  0.251060
#                   contemporary + 1-lagged     0.265190  0.265190
# E2      backward  contemporary                0.190334  0.190334
#                   contemporary + 1-lagged     0.146193  0.146193
#         forward   contemporary                0.190334  0.190334
#                   contemporary + 1-lagged     0.146193  0.146169
# GM      backward  contemporary                0.176563  0.157890
#                   contemporary + 1-lagged     0.050087  0.085362
#         forward   contemporary                0.176563  0.012959
#                   contemporary + 1-lagged     0.050087  0.050087
#
#                                           execution_time
# features_set                                      single       all
# dataset direction features_lag
# E1      backward  contemporary                  0.688195  6.806478
#                   contemporary + 1-lagged       0.757299  7.315034
#         forward   contemporary                  0.633147  6.430187
#                   contemporary + 1-lagged       0.659232  6.633933
# E2      backward  contemporary                  1.122526  7.054950
#                   contemporary + 1-lagged       1.219591  7.271728
#         forward   contemporary                  0.998714  5.996039
#                   contemporary + 1-lagged       1.053389  6.607501
# GM      backward  contemporary                  0.356708  6.942717
#                   contemporary + 1-lagged       0.399291  7.320499
#         forward   contemporary                  0.349754  6.280308
#                   contemporary + 1-lagged       0.356036  6.558476

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_E1_te.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_te_df_to_latex(results_e12gm_te.iloc[:4, :], target_file)
results_e12gm_te.iloc[:4, :].style.pipe(make_te_pretty)
# Out:
# <style type="text/css">
# #T_d1f66_row0_col0, #T_d1f66_row2_col0, #T_d1f66_row2_col1 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_d1f66_row0_col1 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_d1f66_row0_col2, #T_d1f66_row2_col2, #T_d1f66_row2_col3 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_d1f66_row0_col3 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_d1f66_row0_col4, #T_d1f66_row0_col5, #T_d1f66_row1_col4, #T_d1f66_row1_col5, #T_d1f66_row2_col4, #T_d1f66_row2_col5, #T_d1f66_row3_col4, #T_d1f66_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d1f66_row1_col0, #T_d1f66_row1_col1, #T_d1f66_row3_col0, #T_d1f66_row3_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_d1f66_row1_col2, #T_d1f66_row1_col3, #T_d1f66_row3_col2, #T_d1f66_row3_col3 {
#   background-color: #68be70;
#   color: #000000;
# }
# </style>
# <table id="T_d1f66">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1f66_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_d1f66_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_d1f66_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_d1f66_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_d1f66_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_d1f66_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_d1f66_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_d1f66_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_d1f66_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >direction</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1f66_level0_row0" class="row_heading level0 row0" rowspan="4">E1</th>
#       <th id="T_d1f66_level1_row0" class="row_heading level1 row0" rowspan="2">backward</th>
#       <th id="T_d1f66_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_d1f66_row0_col0" class="data row0 col0" >0.457</td>
#       <td id="T_d1f66_row0_col1" class="data row0 col1" >0.405</td>
#       <td id="T_d1f66_row0_col2" class="data row0 col2" >0.251</td>
#       <td id="T_d1f66_row0_col3" class="data row0 col3" >0.231</td>
#       <td id="T_d1f66_row0_col4" class="data row0 col4" >0.69</td>
#       <td id="T_d1f66_row0_col5" class="data row0 col5" >6.81</td>
#     </tr>
#     <tr>
#       <th id="T_d1f66_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_d1f66_row1_col0" class="data row1 col0" >0.421</td>
#       <td id="T_d1f66_row1_col1" class="data row1 col1" >0.421</td>
#       <td id="T_d1f66_row1_col2" class="data row1 col2" >0.265</td>
#       <td id="T_d1f66_row1_col3" class="data row1 col3" >0.265</td>
#       <td id="T_d1f66_row1_col4" class="data row1 col4" >0.76</td>
#       <td id="T_d1f66_row1_col5" class="data row1 col5" >7.32</td>
#     </tr>
#     <tr>
#       <th id="T_d1f66_level1_row2" class="row_heading level1 row2" rowspan="2">forward</th>
#       <th id="T_d1f66_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_d1f66_row2_col0" class="data row2 col0" >0.457</td>
#       <td id="T_d1f66_row2_col1" class="data row2 col1" >0.457</td>
#       <td id="T_d1f66_row2_col2" class="data row2 col2" >0.251</td>
#       <td id="T_d1f66_row2_col3" class="data row2 col3" >0.251</td>
#       <td id="T_d1f66_row2_col4" class="data row2 col4" >0.63</td>
#       <td id="T_d1f66_row2_col5" class="data row2 col5" >6.43</td>
#     </tr>
#     <tr>
#       <th id="T_d1f66_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_d1f66_row3_col0" class="data row3 col0" >0.421</td>
#       <td id="T_d1f66_row3_col1" class="data row3 col1" >0.421</td>
#       <td id="T_d1f66_row3_col2" class="data row3 col2" >0.265</td>
#       <td id="T_d1f66_row3_col3" class="data row3 col3" >0.265</td>
#       <td id="T_d1f66_row3_col4" class="data row3 col4" >0.66</td>
#       <td id="T_d1f66_row3_col5" class="data row3 col5" >6.63</td>
#     </tr>
#   </tbody>
# </table>

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_E2_te.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_te_df_to_latex(results_e12gm_te.iloc[4:8, :], target_file)
results_e12gm_te.iloc[4:8, :].style.pipe(make_te_pretty)
# Out:
# <style type="text/css">
# #T_80dd9_row0_col0, #T_80dd9_row0_col1, #T_80dd9_row2_col0, #T_80dd9_row2_col1 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_80dd9_row0_col2, #T_80dd9_row0_col3, #T_80dd9_row2_col2, #T_80dd9_row2_col3 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_80dd9_row0_col4, #T_80dd9_row0_col5, #T_80dd9_row1_col4, #T_80dd9_row1_col5, #T_80dd9_row2_col4, #T_80dd9_row2_col5, #T_80dd9_row3_col4, #T_80dd9_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_80dd9_row1_col0, #T_80dd9_row1_col1, #T_80dd9_row3_col0 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_80dd9_row1_col2, #T_80dd9_row1_col3, #T_80dd9_row3_col2, #T_80dd9_row3_col3 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_80dd9_row3_col1 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_80dd9">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80dd9_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_80dd9_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_80dd9_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_80dd9_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_80dd9_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_80dd9_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_80dd9_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_80dd9_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_80dd9_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >direction</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80dd9_level0_row0" class="row_heading level0 row0" rowspan="4">E2</th>
#       <th id="T_80dd9_level1_row0" class="row_heading level1 row0" rowspan="2">backward</th>
#       <th id="T_80dd9_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_80dd9_row0_col0" class="data row0 col0" >0.423</td>
#       <td id="T_80dd9_row0_col1" class="data row0 col1" >0.423</td>
#       <td id="T_80dd9_row0_col2" class="data row0 col2" >0.190</td>
#       <td id="T_80dd9_row0_col3" class="data row0 col3" >0.190</td>
#       <td id="T_80dd9_row0_col4" class="data row0 col4" >1.12</td>
#       <td id="T_80dd9_row0_col5" class="data row0 col5" >7.05</td>
#     </tr>
#     <tr>
#       <th id="T_80dd9_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_80dd9_row1_col0" class="data row1 col0" >0.391</td>
#       <td id="T_80dd9_row1_col1" class="data row1 col1" >0.391</td>
#       <td id="T_80dd9_row1_col2" class="data row1 col2" >0.146</td>
#       <td id="T_80dd9_row1_col3" class="data row1 col3" >0.146</td>
#       <td id="T_80dd9_row1_col4" class="data row1 col4" >1.22</td>
#       <td id="T_80dd9_row1_col5" class="data row1 col5" >7.27</td>
#     </tr>
#     <tr>
#       <th id="T_80dd9_level1_row2" class="row_heading level1 row2" rowspan="2">forward</th>
#       <th id="T_80dd9_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_80dd9_row2_col0" class="data row2 col0" >0.423</td>
#       <td id="T_80dd9_row2_col1" class="data row2 col1" >0.423</td>
#       <td id="T_80dd9_row2_col2" class="data row2 col2" >0.190</td>
#       <td id="T_80dd9_row2_col3" class="data row2 col3" >0.190</td>
#       <td id="T_80dd9_row2_col4" class="data row2 col4" >1.00</td>
#       <td id="T_80dd9_row2_col5" class="data row2 col5" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_80dd9_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_80dd9_row3_col0" class="data row3 col0" >0.391</td>
#       <td id="T_80dd9_row3_col1" class="data row3 col1" >0.422</td>
#       <td id="T_80dd9_row3_col2" class="data row3 col2" >0.146</td>
#       <td id="T_80dd9_row3_col3" class="data row3 col3" >0.146</td>
#       <td id="T_80dd9_row3_col4" class="data row3 col4" >1.05</td>
#       <td id="T_80dd9_row3_col5" class="data row3 col5" >6.61</td>
#     </tr>
#   </tbody>
# </table>

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_GM_te.tex")
os.makedirs(os.path.dirname(target_file), exist_ok=True)
export_te_df_to_latex(results_e12gm_te.iloc[8:, :], target_file)
results_e12gm_te.iloc[8:, :].style.pipe(make_te_pretty)
# Out:
# <style type="text/css">
# #T_58b0f_row0_col0, #T_58b0f_row2_col0 {
#   background-color: #2b934b;
#   color: #f1f1f1;
# }
# #T_58b0f_row0_col1 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_58b0f_row0_col2, #T_58b0f_row2_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_58b0f_row0_col3 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_58b0f_row0_col4, #T_58b0f_row0_col5, #T_58b0f_row1_col4, #T_58b0f_row1_col5, #T_58b0f_row2_col4, #T_58b0f_row2_col5, #T_58b0f_row3_col4, #T_58b0f_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_58b0f_row1_col0, #T_58b0f_row3_col0, #T_58b0f_row3_col1 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_58b0f_row1_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_58b0f_row1_col2, #T_58b0f_row3_col2, #T_58b0f_row3_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_58b0f_row1_col3 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_58b0f_row2_col1 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_58b0f_row2_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# </style>
# <table id="T_58b0f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58b0f_level0_col0" class="col_heading level0 col0" colspan="2">score_r2_lag_ar</th>
#       <th id="T_58b0f_level0_col2" class="col_heading level0 col2" colspan="2">score_r2_lag</th>
#       <th id="T_58b0f_level0_col4" class="col_heading level0 col4" colspan="2">execution_time</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >features_set</th>
#       <th id="T_58b0f_level1_col0" class="col_heading level1 col0" >single</th>
#       <th id="T_58b0f_level1_col1" class="col_heading level1 col1" >all</th>
#       <th id="T_58b0f_level1_col2" class="col_heading level1 col2" >single</th>
#       <th id="T_58b0f_level1_col3" class="col_heading level1 col3" >all</th>
#       <th id="T_58b0f_level1_col4" class="col_heading level1 col4" >single</th>
#       <th id="T_58b0f_level1_col5" class="col_heading level1 col5" >all</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="index_name level1" >direction</th>
#       <th class="index_name level2" >features_lag</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58b0f_level0_row0" class="row_heading level0 row0" rowspan="4">GM</th>
#       <th id="T_58b0f_level1_row0" class="row_heading level1 row0" rowspan="2">backward</th>
#       <th id="T_58b0f_level2_row0" class="row_heading level2 row0" >contemporary</th>
#       <td id="T_58b0f_row0_col0" class="data row0 col0" >0.359</td>
#       <td id="T_58b0f_row0_col1" class="data row0 col1" >0.457</td>
#       <td id="T_58b0f_row0_col2" class="data row0 col2" >0.177</td>
#       <td id="T_58b0f_row0_col3" class="data row0 col3" >0.158</td>
#       <td id="T_58b0f_row0_col4" class="data row0 col4" >0.36</td>
#       <td id="T_58b0f_row0_col5" class="data row0 col5" >6.94</td>
#     </tr>
#     <tr>
#       <th id="T_58b0f_level2_row1" class="row_heading level2 row1" >contemporary + 1-lagged</th>
#       <td id="T_58b0f_row1_col0" class="data row1 col0" >0.411</td>
#       <td id="T_58b0f_row1_col1" class="data row1 col1" >0.377</td>
#       <td id="T_58b0f_row1_col2" class="data row1 col2" >0.050</td>
#       <td id="T_58b0f_row1_col3" class="data row1 col3" >0.085</td>
#       <td id="T_58b0f_row1_col4" class="data row1 col4" >0.40</td>
#       <td id="T_58b0f_row1_col5" class="data row1 col5" >7.32</td>
#     </tr>
#     <tr>
#       <th id="T_58b0f_level1_row2" class="row_heading level1 row2" rowspan="2">forward</th>
#       <th id="T_58b0f_level2_row2" class="row_heading level2 row2" >contemporary</th>
#       <td id="T_58b0f_row2_col0" class="data row2 col0" >0.359</td>
#       <td id="T_58b0f_row2_col1" class="data row2 col1" >0.392</td>
#       <td id="T_58b0f_row2_col2" class="data row2 col2" >0.177</td>
#       <td id="T_58b0f_row2_col3" class="data row2 col3" >0.013</td>
#       <td id="T_58b0f_row2_col4" class="data row2 col4" >0.35</td>
#       <td id="T_58b0f_row2_col5" class="data row2 col5" >6.28</td>
#     </tr>
#     <tr>
#       <th id="T_58b0f_level2_row3" class="row_heading level2 row3" >contemporary + 1-lagged</th>
#       <td id="T_58b0f_row3_col0" class="data row3 col0" >0.411</td>
#       <td id="T_58b0f_row3_col1" class="data row3 col1" >0.411</td>
#       <td id="T_58b0f_row3_col2" class="data row3 col2" >0.050</td>
#       <td id="T_58b0f_row3_col3" class="data row3 col3" >0.050</td>
#       <td id="T_58b0f_row3_col4" class="data row3 col4" >0.36</td>
#       <td id="T_58b0f_row3_col5" class="data row3 col5" >6.56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### <a id='toc1_2_3_'></a>[Full version without CMI](#toc0_)

# %% [markdown]
# #### <a id='toc1_2_3_1_'></a>[TEFS](#toc0_)

# %%
target_file = os.path.join(constants.path_table_tex, "e12gm_noCMI_te_full.tex")
export_results_dataframe_te(results_e12gm_noCMI_te, target_file)
results_e12gm_noCMI_te.style.pipe(make_te_all_pretty)
# Out:
# <style type="text/css">
# #T_728c1_row0_col1, #T_728c1_row0_col2 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_728c1_row0_col3 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_728c1_row0_col8 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_728c1_row1_col1, #T_728c1_row1_col2 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_728c1_row1_col3 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_728c1_row1_col8, #T_728c1_row3_col8 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_728c1_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_728c1_row2_col2 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_728c1_row2_col3 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_728c1_row2_col8 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_728c1_row3_col1, #T_728c1_row7_col1 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_728c1_row3_col2, #T_728c1_row7_col2 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_728c1_row3_col3, #T_728c1_row7_col3 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_728c1_row4_col1, #T_728c1_row4_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_728c1_row4_col3 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_728c1_row4_col8, #T_728c1_row20_col8 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_728c1_row5_col1, #T_728c1_row5_col2 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_728c1_row5_col3 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_728c1_row5_col8 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_728c1_row6_col1, #T_728c1_row10_col2 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_728c1_row6_col2 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_728c1_row6_col3 {
#   background-color: #05712f;
#   color: #f1f1f1;
# }
# #T_728c1_row6_col8 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_728c1_row7_col8 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_728c1_row8_col1, #T_728c1_row8_col2 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_728c1_row8_col3 {
#   background-color: #005c25;
#   color: #f1f1f1;
# }
# #T_728c1_row8_col8, #T_728c1_row10_col8, #T_728c1_row11_col8 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_728c1_row9_col1, #T_728c1_row9_col2 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_728c1_row9_col3, #T_728c1_row10_col3, #T_728c1_row17_col3 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_728c1_row9_col8 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_728c1_row10_col1 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_728c1_row11_col1, #T_728c1_row14_col1, #T_728c1_row15_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_728c1_row11_col2, #T_728c1_row14_col2, #T_728c1_row15_col2 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_728c1_row11_col3, #T_728c1_row14_col3, #T_728c1_row15_col3, #T_728c1_row16_col3 {
#   background-color: #006328;
#   color: #f1f1f1;
# }
# #T_728c1_row12_col1, #T_728c1_row12_col2, #T_728c1_row21_col1, #T_728c1_row21_col2 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_728c1_row12_col3 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_728c1_row12_col8 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_728c1_row13_col1, #T_728c1_row13_col2 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_728c1_row13_col3 {
#   background-color: #097532;
#   color: #f1f1f1;
# }
# #T_728c1_row13_col8, #T_728c1_row21_col8 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_728c1_row14_col8 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_728c1_row15_col8, #T_728c1_row23_col8 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_728c1_row16_col1, #T_728c1_row16_col2 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_728c1_row16_col8, #T_728c1_row17_col8, #T_728c1_row18_col8, #T_728c1_row19_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_728c1_row17_col1, #T_728c1_row17_col2 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_728c1_row18_col1 {
#   background-color: #76c578;
#   color: #000000;
# }
# #T_728c1_row18_col2 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_728c1_row18_col3 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_728c1_row19_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_728c1_row19_col2 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_728c1_row19_col3 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_728c1_row20_col1, #T_728c1_row20_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_728c1_row20_col3 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# #T_728c1_row21_col3 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_728c1_row22_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_728c1_row22_col2 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_728c1_row22_col3 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_728c1_row22_col8 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_728c1_row23_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_728c1_row23_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_728c1_row23_col3 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_728c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_728c1_level0_col0" class="col_heading level0 col0" >selected_features</th>
#       <th id="T_728c1_level0_col1" class="col_heading level0 col1" >score_r2</th>
#       <th id="T_728c1_level0_col2" class="col_heading level0 col2" >score_r2_lag</th>
#       <th id="T_728c1_level0_col3" class="col_heading level0 col3" >score_r2_lag_ar</th>
#       <th id="T_728c1_level0_col4" class="col_heading level0 col4" >dataset</th>
#       <th id="T_728c1_level0_col5" class="col_heading level0 col5" >lagfeatures</th>
#       <th id="T_728c1_level0_col6" class="col_heading level0 col6" >lagtarget</th>
#       <th id="T_728c1_level0_col7" class="col_heading level0 col7" >direction</th>
#       <th id="T_728c1_level0_col8" class="col_heading level0 col8" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_728c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_728c1_row0_col0" class="data row0 col0" >E1cyclostationary_mean_tg_12w_3 E1cyclostationary_mean_rr_1w_10 E1cyclostationary_mean_tg_8w_1 E1cyclostationary_mean_tg_6 E1cyclostationary_mean_tg_12w_2 E1cyclostationary_mean_rr_1w_9 E1cyclostationary_mean_tg_0 E1cyclostationary_mean_rr_4w_1</td>
#       <td id="T_728c1_row0_col1" class="data row0 col1" >0.276</td>
#       <td id="T_728c1_row0_col2" class="data row0 col2" >0.276</td>
#       <td id="T_728c1_row0_col3" class="data row0 col3" >0.482</td>
#       <td id="T_728c1_row0_col4" class="data row0 col4" >df_E1_noCMI</td>
#       <td id="T_728c1_row0_col5" class="data row0 col5" >[0]</td>
#       <td id="T_728c1_row0_col6" class="data row0 col6" >[1]</td>
#       <td id="T_728c1_row0_col7" class="data row0 col7" >backward</td>
#       <td id="T_728c1_row0_col8" class="data row0 col8" >717.581s</td>
#     </tr>
#     <tr>
#       <th id="T_728c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_728c1_row1_col0" class="data row1 col0" >E1cyclostationary_mean_rr_12w_0 E1cyclostationary_mean_rr_1w_5 E1cyclostationary_mean_tg_6</td>
#       <td id="T_728c1_row1_col1" class="data row1 col1" >0.254</td>
#       <td id="T_728c1_row1_col2" class="data row1 col2" >0.254</td>
#       <td id="T_728c1_row1_col3" class="data row1 col3" >0.471</td>
#       <td id="T_728c1_row1_col4" class="data row1 col4" >df_E1_noCMI</td>
#       <td id="T_728c1_row1_col5" class="data row1 col5" >[0]</td>
#       <td id="T_728c1_row1_col6" class="data row1 col6" >[1]</td>
#       <td id="T_728c1_row1_col7" class="data row1 col7" >forward</td>
#       <td id="T_728c1_row1_col8" class="data row1 col8" >641.229s</td>
#     </tr>
#     <tr>
#       <th id="T_728c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_728c1_row2_col0" class="data row2 col0" >E1cyclostationary_mean_rr_8w_4 E1cyclostationary_mean_tg_0</td>
#       <td id="T_728c1_row2_col1" class="data row2 col1" >0.261</td>
#       <td id="T_728c1_row2_col2" c

# %% [markdown]
# ### <a id='toc1_2_4_'></a>[TEFS as wrapper on E12GM](#toc0_)

# %% [markdown]
# In this way the method becomes a wrapper because we are making a selection solely by looking at the performance in regression.

# %%
# Load all TEFS simulations
results_files = sorted([file for file in os.listdir(constants.path_results) if file.endswith(".pkl")])
config_list = [file for file in results_files if file.split("_")[0] == "te"]
config_list
# Out:
# ['te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GM_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GM_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GM_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GM_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_ticino_datasetnormal_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_ticino_datasetnormal_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_ticino_datasetnormal_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_ticino_datasetnormal_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_ticino_datasetsnowlakes_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_ticino_datasetsnowlakes_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#  'te_ticino_datasetsnowlakes_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#  'te_ticino_datasetsnowlakes_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl']

# %% [markdown]
# Here I make two plots, one with a single line using fixed train and test, and one with cross-validation, in this case with `KFold`, but a version with `TimeSeriesSplit` is also available.

# %%
for config_name in config_list:
    basename = os.path.splitext(os.path.basename(config_name))[0]
    target_file_train_test = os.path.join(constants.path_figures, "tefs_as_wrapper", f"{basename}_wrapper.pdf")
    target_file_cv = os.path.join(constants.path_figures, "tefs_as_wrapper_cv", f"{basename}_wrapper_cv.pdf")
    if os.path.exists(target_file_train_test) and os.path.exists(target_file_cv):
        print(f"Skipping {config_name}...")
        continue

    print(f"Processing {config_name}...")

    # --------------------- Load simulation ---------------------
    simulation = file_management.load_from_pkl_file(
        os.path.join(
            constants.path_results,
            config_name,
        )
    )

    # --------------------- Load corresponding dataset ---------------------
    basin_name = config_name.split("_")[1]
    datasets, _ = datasets_and_configurations_loaders["te"].get(basin_name)()
    dataset_name = simulation["dataset_name"]
    dataframe = datasets[dataset_name]

    target_columns = ["target"]
    features_columns = dataframe["full"].drop(columns=target_columns).columns

    # --------------------- Select features using threshold (conservative) ---------------------
    selected_features_names_with_threshold = simulation["results"].select_features(simulation["params"]["threshold"])
    n_features_selected_with_threshold = len(selected_features_names_with_threshold)

    # --------------------- Compute test R2 for each number of features ---------------------
    test_r2_train_test = []
    test_r2_cv = []
    num_total_features = len(dataframe["full"].columns) - 1  # -1 because the last column is the target
    for num_features in range(0, num_total_features + 1):
        if num_features == 0:
            selected_features_names = []
        else:
            selected_features_names = simulation["results"].select_n_features(num_features)

        lagfeatures = simulation["params"]["lagfeatures"]
        lagtarget = simulation["params"]["lagtarget"]

        inputs_names_lags = {feature: lagfeatures for feature in selected_features_names}
        inputs_names_lags["target"] = lagtarget

        # --- Compute the train_test version ---
        test_r2_train_test.append(
            regression_analysis(
                inputs_names_lags=inputs_names_lags,
                target_name=target_columns[0],
                df_train=dataframe["train"],
                df_test=dataframe["test"],
            )
        )

        # --- Compute the cross-validation version ---
        # To perform a cross-validation, we need to concatenate the train and test sets
        unified_df = pd.concat([dataframe["train"], dataframe["test"]], axis=0).reset_index(drop=True)

        # Fixed window size
        # n_samples = unified_df.shape[0]
        # n_splits = 5
        # cv_scheme = TimeSeriesSplit(
        #     n_splits=n_splits,
        #     max_train_size=n_samples // (n_splits + 1),
        # )

        # Regular KFold
        cv_scheme = KFold(n_splits=4)  # 4 splits is about using the same test set size

        test_r2_cv.append(
            regression_analysis(
                inputs_names_lags=inputs_names_lags,
                target_name=target_columns[0],
                df=unified_df,
                cv_scheme=cv_scheme,
            )
        )

    test_r2_train_test = np.array(test_r2_train_test)
    test_r2_cv = np.array(test_r2_cv)

    # --------------------- Plot train test version ---------------------
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(test_r2_train_test, marker="o", label="Fixed train-test")
    maxima = np.where(test_r2_train_test == test_r2_train_test.max())[0]
    ax.plot(maxima, test_r2_train_test[maxima], marker="o", color="red", linestyle="None", label="Maximum", markersize=10)
    ax.plot(n_features_selected_with_threshold, test_r2_train_test[n_features_selected_with_threshold], marker="o", color="green", linestyle="None", label="TEFS (conservative)", markersize=10)
    ax.set_xlabel("Number of features")
    ax.set_ylabel("Test $R^2$")

    if simulation["params"]["threshold"] == np.inf:
        threshold_text = "\infty"
    elif simulation["params"]["threshold"] == -np.inf:
        threshold_text = "-\infty"
    else:
        threshold_text = simulation["params"]["threshold"]

    title_text = f"TEFS on basin {basin_name.upper()} with dataset {dataset_name}\n[lagfeatures $={simulation['params']['lagfeatures']}$, lagtarget $={simulation['params']['lagtarget']}$, direction = {simulation['params']['direction']}, threshold $={threshold_text}]$"
    ax.set_title(title_text)
    ax.legend()
    if num_total_features < 30:
        step = 1
    elif num_total_features < 80:
        step = 5
    else:
        step = 10
    ax.set_xticks(range(0, num_total_features + 1, step))
    ax.set_xticklabels(range(0, num_total_features + 1, step))
    ax.set_ylim(-0.1, 0.55)
    ax.grid()

    os.makedirs(os.path.dirname(target_file_train_test), exist_ok=True)
    plt.savefig(target_file_train_test, bbox_inches="tight")
    plt.close(fig)

    # --------------------- Plot cross-validation version ---------------------
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(test_r2_cv.mean(axis=1), marker="o", label="Cross-validation")
    maxima = np.where(test_r2_cv.mean(axis=1) == test_r2_cv.mean(axis=1).max())[0]
    ax.plot(maxima, test_r2_cv.mean(axis=1)[maxima], marker="o", color="red", linestyle="None", label="Maximum", markersize=10)
    ax.plot(n_features_selected_with_threshold, test_r2_cv.mean(axis=1)[n_features_selected_with_threshold], marker="o", color="green", linestyle="None", label="TEFS (conservative)", markersize=10)

    # plot confidence interval bands from cross-validation based on mean and standard deviation (90% confidence)
    alpha = 0.1
    quantile = scipy.stats.norm.ppf(1 - alpha / 2)
    ax.fill_between(range(test_r2_cv.shape[0]), test_r2_cv.mean(axis=1) - test_r2_cv.std(axis=1) * quantile / np.sqrt(test_r2_cv.shape[1]), test_r2_cv.mean(axis=1) + test_r2_cv.std(axis=1) * quantile / np.sqrt(test_r2_cv.shape[1]), alpha=0.3)

    ax.set_xlabel("Number of features")
    ax.set_ylabel("Test $R^2$")

    if simulation["params"]["threshold"] == np.inf:
        threshold_text = "\infty"
    elif simulation["params"]["threshold"] == -np.inf:
        threshold_text = "-\infty"
    else:
        threshold_text = simulation["params"]["threshold"]

    title_text = f"TEFS on basin {basin_name.upper()} with dataset {dataset_name}\n[lagfeatures $={simulation['params']['lagfeatures']}$, lagtarget $={simulation['params']['lagtarget']}$, direction = {simulation['params']['direction']}, threshold $={threshold_text}]$"
    ax.set_title(title_text)
    ax.legend()
    if num_total_features < 30:
        step = 1
    elif num_total_features < 80:
        step = 5
    else:
        step = 10
    ax.set_xticks(range(0, num_total_features + 1, step))
    ax.set_xticklabels(range(0, num_total_features + 1, step))
    ax.set_ylim(-0.1, 0.55)
    ax.grid()

    os.makedirs(os.path.dirname(target_file_cv), exist_ok=True)
    plt.savefig(target_file_cv, bbox_inches="tight")
    plt.close(fig)
# Out:
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_noCMI_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_ticino_datasetnormal_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_ticino_datasetnormal_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_ticino_datasetnormal_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_ticino_datasetnormal_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_ticino_datasetsnowlakes_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_ticino_datasetsnowlakes_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_ticino_datasetsnowlakes_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_ticino_datasetsnowlakes_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...

# %% [markdown]
# ### <a id='toc1_2_5_'></a>[Linking the wrapper to the original filter method](#toc0_)

# %% [markdown]
# Here I look for all configurations without CMI and match them to those with CMI. I show the plot above where I see the algorithm as a wrapper and highlight with vertical bars the points at which the variables chosen in the version with CMI were added/removed. There is also the option to choose variables manually (ideally the most common ones "by eye").

# %%
config_matches = []
for config_name in config_list:
    if "noCMI" in config_name and config_name.replace("_noCMI", "") in config_list:
        config_matches.append((config_name, config_name.replace("_noCMI", "")))

config_matches[:2]
# Out:
# [('te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl',
#   'te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl'),
#  ('te_e12gm_datasetdf_E1_noCMI_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl',
#   'te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl')]

# %%
for config_name_noCMI, config_name in config_matches:
    basename = os.path.splitext(os.path.basename(config_name_noCMI))[0]
    target_file = os.path.join(constants.path_figures, "tefs_as_wrapper_mapping_filter", f"{basename}_wrapper_mapping_filter.pdf")
    if os.path.exists(target_file):
        print(f"Skipping {config_name}...")
        continue

    print(f"Processing {config_name}...")

    simulation_noCMI = file_management.load_from_pkl_file(
        os.path.join(
            constants.path_results,
            config_name_noCMI,
        )
    )

    simulation = file_management.load_from_pkl_file(
        os.path.join(
            constants.path_results,
            config_name,
        )
    )

    # feature selected with CMI
    basin_name = config_name.split("_")[1]
    datasets, _ = datasets_and_configurations_loaders["te"].get(basin_name)()
    dataset_name = simulation["dataset_name"]
    dataframe = datasets[dataset_name]
    target_columns = ["target"]
    features_columns = dataframe["full"].drop(columns=target_columns).columns

    selected_features_names_with_threshold = simulation["results"].select_features(simulation["params"]["threshold"])
    n_features_selected_with_threshold = len(selected_features_names_with_threshold)

    # choose manually
    selected_features_names_with_threshold = ["E1cyclostationary_mean_rr_4w_1", "E2cyclostationary_mean_tg_0"]

    # Load the noCMI version and process it
    basin_name = config_name_noCMI.split("_")[1]
    datasets, _ = datasets_and_configurations_loaders["te"].get(basin_name)()
    dataset_name_noCMI = simulation_noCMI["dataset_name"]
    dataframe_noCMI = datasets[dataset_name_noCMI]
    target_columns = ["target"]
    features_columns_noCMI = dataframe_noCMI["full"].drop(columns=target_columns).columns

    test_r2_train_test = []

    selected_features_names_previous = []  # new part
    corresponding_features_indexes = {}  # new part

    num_total_features = len(dataframe_noCMI["full"].columns) - 1  # -1 because the last column is the target
    for num_features in range(0, num_total_features + 1):
        if num_features == 0:
            selected_features_names = []
        else:
            selected_features_names_previous = selected_features_names.copy()  # new part
            selected_features_names = simulation_noCMI["results"].select_n_features(num_features)

            # if the feature that has been just added is in selected_features_names_with_threshold, add num_features to corresponding_features_indexes
            # looking at the set difference
            new_feature_name = list(set(selected_features_names).difference(set(selected_features_names_previous)))[0]
            if new_feature_name in selected_features_names_with_threshold:
                corresponding_features_indexes[num_features] = new_feature_name

        lagfeatures = simulation_noCMI["params"]["lagfeatures"]
        lagtarget = simulation_noCMI["params"]["lagtarget"]

        inputs_names_lags = {feature: lagfeatures for feature in selected_features_names}
        inputs_names_lags["target"] = lagtarget

        # --- Compute the train_test version ---
        test_r2_train_test.append(
            regression_analysis(
                inputs_names_lags=inputs_names_lags,
                target_name=target_columns[0],
                df_train=dataframe_noCMI["train"],
                df_test=dataframe_noCMI["test"],
            )
        )

    test_r2_train_test = np.array(test_r2_train_test)

    # --------------------- Plot ---------------------
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.plot(test_r2_train_test, marker="o", label="Fixed train-test")

    # Get the default color cycle
    color_cycle = plt.rcParams["axes.prop_cycle"].by_key()["color"]

    # plot vertical lines in corresponding_features_indexes
    for i, (key, value) in enumerate(corresponding_features_indexes.items()):
        ax.axvline(x=key, linestyle="--", color=color_cycle[i + 1 % len(color_cycle)], label=f"{value}")

    maxima = np.where(test_r2_train_test == test_r2_train_test.max())[0]
    ax.plot(maxima, test_r2_train_test[maxima], marker="o", color="red", linestyle="None", label="Maximum", markersize=10)
    ax.plot(n_features_selected_with_threshold, test_r2_train_test[n_features_selected_with_threshold], marker="o", color="green", linestyle="None", label="TEFS (conservative)", markersize=10)
    ax.set_xlabel("Number of features")
    ax.set_ylabel("Test $R^2$")

    if simulation["params"]["threshold"] == np.inf:
        threshold_text = "\infty"
    elif simulation["params"]["threshold"] == -np.inf:
        threshold_text = "-\infty"
    else:
        threshold_text = simulation["params"]["threshold"]

    title_text = f"TEFS on basin {basin_name.upper()} with dataset {dataset_name}\n[lagfeatures $={simulation['params']['lagfeatures']}$, lagtarget $={simulation['params']['lagtarget']}$, direction = {simulation['params']['direction']}, threshold $={threshold_text}]$"
    ax.set_title(title_text)
    ax.legend()
    if num_total_features < 30:
        step = 1
    elif num_total_features < 80:
        step = 5
    else:
        step = 10

    ax.set_xticks(range(0, num_total_features + 1, step))
    ax.set_xticklabels(range(0, num_total_features + 1, step))
    ax.set_ylim(-0.1, 0.55)
    ax.grid()

    os.makedirs(os.path.dirname(target_file), exist_ok=True)
    plt.savefig(target_file, bbox_inches="tight")
    plt.close(fig)
# Out:
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E1allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_E2allfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GM_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0,1]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionbackward_threshold0_k10.pkl...
# Skipping te_e12gm_datasetdf_GMallfeatures_lagfeatures[0]_lagtarget[1]_directionforward_thresholdinf_k10.pkl...
